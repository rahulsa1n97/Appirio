# %%
import pandas as pd
import numpy as np
import itertools

# %%
data=pd.read_csv('aprior.csv')
data
# Out:
#    tid               item
# 0  100     bread,Milk,tea
# 1  101      bread,Milk,pa
# 2  102        Milk,tea,zz
# 3  103  bread,Milk,tea,zz
# 4  104  bread,Milk,tea,zz

# %%
min_support=50  #input 
no_of_item=int((min_support/100)*len(data))
no_of_item
# Out:
# 2

# %%
#convert all tranaction element to list
column=data.columns
d=data[column[1]]
list_data=[]
for i in d:
    p=[]
    for j in range(len(i)):
        if i[j]==' ' or i[j]==',':
            continue
        p.append(i[j])
    list_data.append(p)
print(d)

def c1_matrix(data):
    unique_element=[]
    for i in data:
        for j in i:
            if j not in unique_element:
                unique_element.append(j)
    unique_element.sort()
    c1=[]
    for i in unique_element:
        c1.append([i])
    return c1

c1=c1_matrix(list_data)
print(c1)
# Out:
# 0       bread,Milk,tea
# 1        bread,Milk,pa
# 2          Milk,tea,zz
# 3    bread,Milk,tea,zz
# 4    bread,Milk,tea,zz
# Name: item, dtype: object
# [['M'], ['a'], ['b'], ['d'], ['e'], ['i'], ['k'], ['l'], ['p'], ['r'], ['t'], ['z']]

# %%
#calculate c_i
def calculate_ci(l_i): 
    length=len(l_i[0])
    c_i=[]
    if length==1:
        for i in range(len(l_i)-1):
            for j in range(i+1,len(l_i)):
                p=l_i[i]
                q=l_i[j]
                c_i.append([p[0],q[0]])
        
        return c_i
    else:
        for i in l_i:
            union=[]
            for j in l_i:
                if i!=j:
                    p=set(i)
                    q=set(j)
                    common=p&q
                    common_len=len(common)
                    if common_len==length-1:
                        if i[0]==j[0]:
                            union=list(q.union(p))
                            p=union.sort()
                            
                            p=list(itertools.combinations(union, length))
                            
                            count=0
                            for k in p:
                                if list(k) in l_i:
                                    count+=1
                            if count==len(p):
                                if union not in c_i:
                                    c_i.append(union)
        return c_i
                                
                                      
# calculate c_i support
def ci_support(c_i,data):
    support=[]
    #print(c_i)
    for i in c_i:
        p=0
        for j in data:
            #print(i,j)
            c=set(i)&set(j)
            #print(c)
            if len(c)==len(i):
                p+=1
        support.append(p)
    return support

# %%
def calculate_l(c_i,c_value):
    l_matrix=[]
    l_value=[]
    for i in range(len(c_value)):
        if int(c_value[i])>=no_of_item:
            l_matrix.append(c_i[i])
            l_value.append(c_value[i])
    return l_matrix,l_value

#calculate_l(ci_matrix,support)

# %%
def apprior(data):
    total_li=[]
    c1=c1_matrix(data)
    c1_support=ci_support(c1,data)
    l1,l1_support=calculate_l(c1,c1_support)
    #print(l1,l1_support)
    while True:
        ci=calculate_ci(l1)
        ci_suppor=ci_support(ci,data)    
        l1,li_support=calculate_l(ci,ci_suppor)
        if len(l1)==0:
            break
        total_li.append(l1)

    return total_li

li_element=apprior(list_data)
print(li_element[-1])
# Out:
# [['M', 'a', 'b', 'd', 'e', 'i', 'k', 'l', 'r', 't', 'z']]

# %%
def subset(x):
    sub_set=[]
    p=[]
    for i in range(1,len(x)):
        p+=list(itertools.combinations(x,i))
    sub_set.append(p)
    return sub_set
    

def rule(li,confidance):
    ap_rule=[]
    for i in li:
        sub_set=subset(i)
        sub_set=sub_set[0]
        for k in range(len(sub_set)):
            j=sub_set[k]
            i_c=list(set(i)^set(j))
            support_c=ci_support([i],list_data)
            support_ci=ci_support(i_c,list_data)
            if support_c[0]/support_ci[0]>confidance:
                ap_rule.append([j,i_c])
    return ap_rule
confidance=50
rule(li_element[-1],confidance/100)
# Out:
# [[('r',), ['z', 'b', 'l', 'M', 'e', 'i', 'd', 't', 'k', 'a']],
#  [('M', 'r'), ['z', 'b', 'l', 'e', 'i', 'd', 't', 'k', 'a']],
#  [('a', 'r'), ['z', 'b', 'M', 'l', 'e', 'i', 'd', 't', 'k']],
#  [('b', 'r'), ['z', 'e', 'i', 't', 'a', 'M', 'l', 'd', 'k']],
#  [('d', 'r'), ['z', 'b', 'M', 'l', 'e', 'i', 't', 'k', 'a']],
#  [('e', 'r'), ['z', 'b', 'M', 'l', 'i', 'd', 't', 'k', 'a']],
#  [('i', 'r'), ['z', 'b', 'M', 'l', 'e', 'd', 't', 'k', 'a']],
#  [('k', 'r'), ['z', 'b', 'M', 'l', 'e', 'i', 'd', 't', 'a']],
#  [('l', 'r'), ['z', 'b', 'M', 'e', 'i', 'd', 't', 'k', 'a']],
#  [('r', 't'), ['z', 'b', 'M', 'l', 'e', 'i', 'd', 'k', 'a']],
#  [('M', 'a', 'r'), ['z', 'b', 'l', 'e', 'i', 'd', 't', 'k']],
#  [('M', 'd', 'r'), ['z', 'b', 'l', 'e', 'i', 't', 'k', 'a']],
#  [('M', 'e', 'r'), ['z', 'b', 'l', 'i', 'd', 't', 'k', 'a']],
#  [('M', 'i', 'r'), ['z', 'b', 'l', 'e', 'd', 't', 'k', 'a']],
#  [('M', 'k', 'r'), ['z', 'b', 'l', 'e', 'i', 'd', 't', 'a']],
#  [('M', 'l', 'r'), ['z', 'b', 'e', 'i', 'd', 't', 'k', 'a']],
#  [('M', 'r', 't'), ['z', 'b', 'l', 'e', 'i', 'd', 'k', 'a']],
#  [('a', 'b', 'r'), ['z', 'e', 'i', 't', 'l', 'M', 'd', 'k']],
#  [('a', 'd', 'r'), ['z', 'b', 'M', 'l', 'e', 'i', 't', 'k']],
#  [('a', 'e', 'r'), ['z', 'b', 'M', 'l', 'i', 'd', 't', 'k']],
#  [('a', 'i', 'r'), ['z', 'b', 'M', 'l', 'e', 'd', 't', 'k']],
#  [('a', 'k', 'r'), ['z', 'b', 'M', 'l', 'e', 'i', 'd', 't']],
#  [('a', 'l', 'r'), ['z', 'b', 'M', 'e', 'i', 'd', 't', 'k']],
#  [('a', 'r', 't'), ['z', 'b', 'M', 'l', 'e', 'i', 'd', 'k']],
#  [('b', 'e', 'r'), ['z', 'i', 't', 'a', 'l', 'M', 'd', 'k']],
#  [('b', 'i', 'r'), ['z', 'e', 't', 'a', 'l', 'M', 'd', 'k']],
#  [('b', 'k', 'r'), ['z', 'e', 'i', 't', 'a', 'l', 'M', 'd']],
#  [('b', 'r', 't'), ['z', 'e', 'i', 'a', 'l', 'M', 'd', 'k']],
#  [('d', 'e', 'r'), ['z', 'b', 'M', 'l', 'i', 't', 'k', 'a']],
#  [('d', 'i', 'r'), ['z', 'b', 'M', 'l', 'e', 't', 'k', 'a']],
#  [('d', 'k', 'r'), ['z', 'b', 'M', 'l', 'e', 'i', 't', 'a']],
#  [('d', 'l', 'r'), ['z', 'b', 'M', 'e', 'i', 't', 'k', 'a']],
#  [('d', 'r', 't'), ['z', 'b', 'M', 'l', 'e', 'i', 'k', 'a']],
#  [('e', 'i', 'r'), ['z', 'b', 'M', 'l', 'd', 't', 'k', 'a']],
#  [('e', 'k', 'r'), ['z', 'b', 'M', 'l', 'i', 'd', 't', 'a']],
#  [('e', 'l', 'r'), ['z', 'b', 'M', 'i', 'd', 't', 'k', 'a']],
#  [('e', 'r', 't'), ['z', 'b', 'M', 'l', 'i', 'd', 'k', 'a']],
#  [('i', 'k', 'r'), ['z', 'b', 'M', 'l', 'e', 'd', 't', 'a']],
#  [('i', 'l', 'r'), ['z', 'b', 'M', 'e', 'd', 't', 'k', 'a']],
#  [('i', 'r', 't'), ['z', 'b', 'M', 'l', 'e', 'd', 'k', 'a']],
#  [('k', 'l', 'r'), ['z', 'b', 'M', 'e', 'i', 'd', 't', 'a']],
#  [('k', 'r', 't'), ['z', 'b', 'M', 'l', 'e', 'i', 'd', 'a']],
#  [('l', 'r', 't'), ['z', 'b', 'M', 'e', 'i', 'd', 'k', 'a']],
#  [('M', 'a', 'b', 'r'), ['z', 'l', 'e', 'i', 'd', 't', 'k']],
#  [('M', 'a', 'd', 'r'), ['z', 'b', 'l', 'e', 'i', 't', 'k']],
#  [('M', 'a', 'e', 'r'), ['z', 'b', 'l', 'i', 'd', 't', 'k']],
#  [('M', 'a', 'i', 'r'), ['z', 'b', 'l', 'e', 'd', 't', 'k']],
#  [('M', 'a', 'k', 'r'), ['z', 'b', 'l', 'e', 'i', 'd', 't']],
#  [('M', 'a', 'l', 'r'), ['z', 'b', 'e', 'i', 'd', 't', 'k']],
#  [('M', 'a', 'r', 't'), ['z', 'b', 'l', 'e', 'i', 'd', 'k']],
#  [('M', 'b', 'd', 'r'), ['z', 'l', 'e', 'i', 't', 'k', 'a']],
#  [('M', 'b', 'e', 'r'), ['z', 'l', 'i', 'd', 't', 'k', 'a']],
#  [('M', 'b', 'i', 'r'), ['z', 'l', 'e', 'd', 't', 'k', 'a']],
#  [('M', 'b', 'k', 'r'), ['z', 'l', 'e', 'i', 'd', 't', 'a']],
#  [('M', 'b', 'l', 'r'), ['z', 'e', 'i', 'd', 't', 'k', 'a']],
#  [('M', 'b', 'r', 't'), ['z', 'l', 'e', 'i', 'd', 'k', 'a']],
#  [('M', 'd', 'e', 'r'), ['z', 'b', 'l', 'i', 't', 'k', 'a']],
#  [('M', 'd', 'i', 'r'), ['z', 'b', 'l', 'e', 't', 'k', 'a']],
#  [('M', 'd', 'k', 'r'), ['z', 'b', 'l', 'e', 'i', 't', 'a']],
#  [('M', 'd', 'l', 'r'), ['z', 'b', 'e', 'i', 't', 'k', 'a']],
#  [('M', 'd', 'r', 't'), ['z', 'b', 'l', 'e', 'i', 'k', 'a']],
#  [('M', 'e', 'i', 'r'), ['z', 'b', 'l', 'd', 't', 'k', 'a']],
#  [('M', 'e', 'k', 'r'), ['z', 'b', 'l', 'i', 'd', 't', 'a']],
#  [('M', 'e', 'l', 'r'), ['z', 'b', 'i', 'd', 't', 'k', 'a']],
#  [('M', 'e', 'r', 't'), ['z', 'b', 'l', 'i', 'd', 'k', 'a']],
#  [('M', 'i', 'k', 'r'), ['z', 'b', 'l', 'e', 'd', 't', 'a']],
#  [('M', 'i', 'l', 'r'), ['z', 'b', 'e', 'd', 't', 'k', 'a']],
#  [('M', 'i', 'r', 't'), ['z', 'b', 'l', 'e', 'd', 'k', 'a']],
#  [('M', 'k', 'l', 'r'), ['z', 'b', 'e', 'i', 'd', 't', 'a']],
#  [('M', 'k', 'r', 't'), ['z', 'b', 'l', 'e', 'i', 'd', 'a']],
#  [('M', 'l', 'r', 't'), ['z', 'b', 'e', 'i', 'd', 'k', 'a']],
#  [('a', 'b', 'd', 'r'), ['z', 'M', 'l', 'e', 'i', 't', 'k']],
#  [('a', 'b', 'e', 'r'), ['z', 'M', 'l', 'i', 'd', 't', 'k']],
#  [('a', 'b', 'i', 'r'), ['z', 'M', 'l', 'e', 'd', 't', 'k']],
#  [('a', 'b', 'k', 'r'), ['z', 'M', 'l', 'e', 'i', 'd', 't']],
#  [('a', 'b', 'l', 'r'), ['z', 'M', 'e', 'i', 'd', 't', 'k']],
#  [('a', 'b', 'r', 't'), ['z', 'M', 'l', 'e', 'i', 'd', 'k']],
#  [('a', 'd', 'e', 'r'), ['z', 'b', 'M', 'l', 'i', 't', 'k']],
#  [('a', 'd', 'i', 'r'), ['z', 'b', 'M', 'l', 'e', 't', 'k']],
#  [('a', 'd', 'k', 'r'), ['z', 'b', 'M', 'l', 'e', 'i', 't']],
#  [('a', 'd', 'l', 'r'), ['z', 'b', 'M', 'e', 'i', 't', 'k']],
#  [('a', 'd', 'r', 't'), ['z', 'b', 'M', 'l', 'e', 'i', 'k']],
#  [('a', 'e', 'i', 'r'), ['z', 'b', 'M', 'l', 'd', 't', 'k']],
#  [('a', 'e', 'k', 'r'), ['z', 'b', 'M', 'l', 'i', 'd', 't']],
#  [('a', 'e', 'l', 'r'), ['z', 'b', 'M', 'i', 'd', 't', 'k']],
#  [('a', 'e', 'r', 't'), ['z', 'b', 'M', 'l', 'i', 'd', 'k']],
#  [('a', 'i', 'k', 'r'), ['z', 'b', 'M', 'l', 'e', 'd', 't']],
#  [('a', 'i', 'l', 'r'), ['z', 'b', 'M', 'e', 'd', 't', 'k']],
#  [('a', 'i', 'r', 't'), ['z', 'b', 'M', 'l', 'e', 'd', 'k']],
#  [('a', 'k', 'l', 'r'), ['z', 'b', 'M', 'e', 'i', 'd', 't']],
#  [('a', 'k', 'r', 't'), ['z', 'b', 'M', 'l', 'e', 'i', 'd']],
#  [('a', 'l', 'r', 't'), ['z', 'b', 'M', 'e', 'i', 'd', 'k']],
#  [('b', 'd', 'e', 'r'), ['z', 'M', 'l', 'i', 't', 'k', 'a']],
#  [('b', 'd', 'i', 'r'), ['z', 'M', 'l', 'e', 't', 'k', 'a']],
#  [('b', 'd', 'k', 'r'), ['z', 'M', 'l', 'e', 'i', 't', 'a']],
#  [('b', 'd', 'l', 'r'), ['z', 'M', 'e', 'i', 't', 'k', 'a']],
#  [('b', 'd', 'r', 't'), ['z', 'M', 'l', 'e', 'i', 'k', 'a']],
#  [('b', 'e', 'i', 'r'), ['z', 'M', 'l', 'd', 't', 'k', 'a']],
#  [('b', 'e', 'k', 'r'), ['z', 'M', 'l', 'i', 'd', 't', 'a']],
#  [('b', 'e', 'l', 'r'), ['z', 'M', 'i', 'd', 't', 'k', 'a']],
#  [('b', 'e', 'r', 't'), ['z', 'M', 'l', 'i', 'd', 'k', 'a']],
#  [('b', 'i', 'k', 'r'), ['z', 'M', 'l', 'e', 'd', 't', 'a']],
#  [('b', 'i', 'l', 'r'), ['z', 'M', 'e', 'd', 't', 'k', 'a']],
#  [('b', 'i', 'r', 't'), ['z', 'M', 'l', 'e', 'd', 'k', 'a']],
#  [('b', 'k', 'l', 'r'), ['z', 'M', 'e', 'i', 'd', 't', 'a']],
#  [('b', 'k', 'r', 't'), ['z', 'M', 'l', 'e', 'i', 'd', 'a']],
#  [('b', 'l', 'r', 't'), ['z', 'M', 'e', 'i', 'd', 'k', 'a']],
#  [('d', 'e', 'i', 'r'), ['z', 'b', 'M', 'l', 't', 'k', 'a']],
#  [('d', 'e', 'k', 'r'), ['z', 'b', 'M', 'l', 'i', 't', 'a']],
#  [('d', 'e', 'l', 'r'), ['z', 'b', 'M', 'i', 't', 'k', 'a']],
#  [('d', 'e', 'r', 't'), ['z', 'b', 'M', 'l', 'i', 'k', 'a']],
#  [('d', 'i', 'k', 'r'), ['z', 'b', 'M', 'l', 'e', 't', 'a']],
#  [('d', 'i', 'l', 'r'), ['z', 'b', 'M', 'e', 't', 'k', 'a']],
#  [('d', 'i', 'r', 't'), ['z', 'b', 'M', 'l', 'e', 'k', 'a']],
#  [('d', 'k', 'l', 'r'), ['z', 'b', 'M', 'e', 'i', 't', 'a']],
#  [('d', 'k', 'r', 't'), ['z', 'b', 'M', 'l', 'e', 'i', 'a']],
#  [('d', 'l', 'r', 't'), ['z', 'b', 'M', 'e', 'i', 'k', 'a']],
#  [('e', 'i', 'k', 'r'), ['z', 'b', 'M', 'l', 'd', 't', 'a']],
#  [('e', 'i', 'l', 'r'), ['z', 'b', 'M', 'd', 't', 'k', 'a']],
#  [('e', 'i', 'r', 't'), ['z', 'b', 'M', 'l', 'd', 'k', 'a']],
#  [('e', 'k', 'l', 'r'), ['z', 'b', 'M', 'i', 'd', 't', 'a']],
#  [('e', 'k', 'r', 't'), ['z', 'b', 'M', 'l', 'i', 'd', 'a']],
#  [('e', 'l', 'r', 't'), ['z', 'b', 'M', 'i', 'd', 'k', 'a']],
#  [('i', 'k', 'l', 'r'), ['z', 'b', 'M', 'e', 'd', 't', 'a']],
#  [('i', 'k', 'r', 't'), ['z', 'b', 'M', 'l', 'e', 'd', 'a']],
#  [('i', 'l', 'r', 't'), ['z', 'b', 'M', 'e', 'd', 'k', 'a']],
#  [('k', 'l', 'r', 't'), ['z', 'b', 'M', 'e', 'i', 'd', 'a']],
#  [('M', 'a', 'b', 'd', 'r'), ['z', 'l', 'e', 'i', 't', 'k']],
#  [('M', 'a', 'b', 'e', 'r'), ['z', 'l', 'i', 'd', 't', 'k']],
#  [('M', 'a', 'b', 'i', 'r'), ['z', 'l', 'e', 'd', 't', 'k']],
#  [('M', 'a', 'b', 'k', 'r'), ['z', 'l', 'e', 'i', 'd', 't']],
#  [('M', 'a', 'b', 'l', 'r'), ['z', 'e', 'i', 'd', 't', 'k']],
#  [('M', 'a', 'b', 'r', 't'), ['z', 'l', 'e', 'i', 'd', 'k']],
#  [('M', 'a', 'd', 'e', 'r'), ['z', 'b', 'l', 'i', 't', 'k']],
#  [('M', 'a', 'd', 'i', 'r'), ['z', 'b', 'l', 'e', 't', 'k']],
#  [('M', 'a', 'd', 'k', 'r'), ['z', 'b', 'e', 'i', 't', 'l']],
#  [('M', 'a', 'd', 'l', 'r'), ['z', 'b', 'e', 'i', 't', 'k']],
#  [('M', 'a', 'd', 'r', 't'), ['z', 'b', 'e', 'i', 'l', 'k']],
#  [('M', 'a', 'e', 'i', 'r'), ['z', 'b', 'l', 'd', 't', 'k']],
#  [('M', 'a', 'e', 'k', 'r'), ['z', 'b', 'l', 'i', 'd', 't']],
#  [('M', 'a', 'e', 'l', 'r'), ['z', 'b', 'i', 'd', 't', 'k']],
#  [('M', 'a', 'e', 'r', 't'), ['z', 'b', 'l', 'i', 'd', 'k']],
#  [('M', 'a', 'i', 'k', 'r'), ['z', 'b', 'l', 'e', 'd', 't']],
#  [('M', 'a', 'i', 'l', 'r'), ['z', 'b', 'e', 'd', 't', 'k']],
#  [('M', 'a', 'i', 'r', 't'), ['z', 'b', 'l', 'e', 'd', 'k']],
#  [('M', 'a', 'k', 'l', 'r'), ['z', 'b', 'e', 'i', 'd', 't']],
#  [('M', 'a', 'k', 'r', 't'), ['z', 'b', 'e', 'i', 'l', 'd']],
#  [('M', 'a', 'l', 'r', 't'), ['z', 'b', 'e', 'i', 'd', 'k']],
#  [('M', 'b', 'd', 'e', 'r'), ['z', 'l', 'i', 't', 'k', 'a']],
#  [('M', 'b', 'd', 'i', 'r'), ['z', 'l', 'e', 't', 'k', 'a']],
#  [('M', 'b', 'd', 'k', 'r'), ['z', 'l', 'e', 'i', 't', 'a']],
#  [('M', 'b', 'd', 'l', 'r'), ['z', 'e', 'i', 't', 'k', 'a']],
#  [('M', 'b', 'd', 'r', 't'), ['z', 'l', 'e', 'i', 'k', 'a']],
#  [('M', 'b', 'e', 'i', 'r'), ['z', 'l', 'd', 't', 'k', 'a']],
#  [('M', 'b', 'e', 'k', 'r'), ['z', 'l', 'i', 'd', 't', 'a']],
#  [('M', 'b', 'e', 'l', 'r'), ['z', 'i', 'd', 't', 'k', 'a']],
#  [('M', 'b', 'e', 'r', 't'), ['z', 'l', 'i', 'd', 'k', 'a']],
#  [('M', 'b', 'i', 'k', 'r'), ['z', 'l', 'e', 'd', 't', 'a']],
#  [('M', 'b', 'i', 'l', 'r'), ['z', 'e', 'd', 't', 'k', 'a']],
#  [('M', 'b', 'i', 'r', 't'), ['z', 'l', 'e', 'd', 'k', 'a']],
#  [('M', 'b', 'k', 'l', 'r'), ['z', 'e', 'i', 'd', 't', 'a']],
#  [('M', 'b', 'k', 'r', 't'), ['z', 'l', 'e', 'i', 'd', 'a']],
#  [('M', 'b', 'l', 'r', 't'), ['z', 'e', 'i', 'd', 'k', 'a']],
#  [('M', 'd', 'e', 'i', 'r'), ['z', 'b', 'l', 't', 'k', 'a']],
#  [('M', 'd', 'e', 'k', 'r'), ['z', 'b', 'l', 'i', 't', 'a']],
#  [('M', 'd', 'e', 'l', 'r'), ['z', 'b', 'i', 't', 'k', 'a']],
#  [('M', 'd', 'e', 'r', 't'), ['z', 'b', 'l', 'i', 'k', 'a']],
#  [('M', 'd', 'i', 'k', 'r'), ['z', 'b', 'l', 'e', 't', 'a']],
#  [('M', 'd', 'i', 'l', 'r'), ['z', 'b', 'e', 't', 'k', 'a']],
#  [('M', 'd', 'i', 'r', 't'), ['z', 'b', 'l', 'e', 'k', 'a']],
#  [('M', 'd', 'k', 'l', 'r'), ['z', 'b', 'e', 'i', 't', 'a']],
#  [('M', 'd', 'k', 'r', 't'), ['z', 'b', 'e', 'i', 'a', 'l']],
#  [('M', 'd', 'l', 'r', 't'), ['z', 'b', 'e', 'i', 'k', 'a']],
#  [('M', 'e', 'i', 'k', 'r'), ['z', 'b', 'l', 'd', 't', 'a']],
#  [('M', 'e', 'i', 'l', 'r'), ['z', 'b', 'd', 't', 'k', 'a']],
#  [('M', 'e', 'i', 'r', 't'), ['z', 'b', 'l', 'd', 'k', 'a']],
#  [('M', 'e', 'k', 'l', 'r'), ['z', 'b', 'i', 'd', 't', 'a']],
#  [('M', 'e', 'k', 'r', 't'), ['z', 'b', 'l', 'i', 'd', 'a']],
#  [('M', 'e', 'l', 'r', 't'), ['z', 'b', 'i', 'd', 'k', 'a']],
#  [('M', 'i', 'k', 'l', 'r'), ['z', 'b', 'e', 'd', 't', 'a']],
#  [('M', 'i', 'k', 'r', 't'), ['z', 'b', 'l', 'e', 'd', 'a']],
#  [('M', 'i', 'l', 'r', 't'), ['z', 'b', 'e', 'd', 'k', 'a']],
#  [('M', 'k', 'l', 'r', 't'), ['z', 'b', 'e', 'i', 'd', 'a']],
#  [('a', 'b', 'd', 'e', 'r'), ['z', 'l', 'M', 'i', 't', 'k']],
#  [('a', 'b', 'd', 'i', 'r'), ['z', 'l', 'M', 'e', 't', 'k']],
#  [('a', 'b', 'd', 'k', 'r'), ['z', 'l', 'M', 'e', 'i', 't']],
#  [('a', 'b', 'd', 'l', 'r'), ['z', 'M', 'e', 'i', 't', 'k']],
#  [('a', 'b', 'd', 'r', 't'), ['z', 'l', 'M', 'e', 'i', 'k']],
#  [('a', 'b', 'e', 'i', 'r'), ['z', 'l', 'M', 'd', 't', 'k']],
#  [('a', 'b', 'e', 'k', 'r'), ['z', 'l', 'M', 'i', 'd', 't']],
#  [('a', 'b', 'e', 'l', 'r'), ['z', 'M', 'i', 'd', 't', 'k']],
#  [('a', 'b', 'e', 'r', 't'), ['z', 'l', 'M', 'i', 'd', 'k']],
#  [('a', 'b', 'i', 'k', 'r'), ['z', 'l', 'M', 'e', 'd', 't']],
#  [('a', 'b', 'i', 'l', 'r'), ['z', 'M', 'e', 'd', 't', 'k']],
#  [('a', 'b', 'i', 'r', 't'), ['z', 'l', 'M', 'e', 'd', 'k']],
#  [('a', 'b', 'k', 'l', 'r'), ['z', 'M', 'e', 'i', 'd', 't']],
#  [('a', 'b', 'k', 'r', 't'), ['z', 'l', 'M', 'e', 'i', 'd']],
#  [('a', 'b', 'l', 'r', 't'), ['z', 'M', 'e', 'i', 'd', 'k']],
#  [('a', 'd', 'e', 'i', 'r'), ['z', 'b', 't', 'l', 'M', 'k']],
#  [('a', 'd', 'e', 'k', 'r'), ['z', 'b', 'i', 't', 'l', 'M']],
#  [('a', 'd', 'e', 'l', 'r'), ['z', 'b', 'M', 'i', 't', 'k']],
#  [('a', 'd', 'e', 'r', 't'), ['z', 'b', 'i', 'l', 'M', 'k']],
#  [('a', 'd', 'i', 'k', 'r'), ['z', 'b', 'e', 't', 'l', 'M']],
#  [('a', 'd', 'i', 'l', 'r'), ['z', 'b', 'M', 'e', 't', 'k']],
#  [('a', 'd', 'i', 'r', 't'), ['z', 'b', 'e', 'l', 'M', 'k']],
#  [('a', 'd', 'k', 'l', 'r'), ['z', 'b', 'M', 'e', 'i', 't']],
#  [('a', 'd', 'k', 'r', 't'), ['z', 'b', 'e', 'i', 'l', 'M']],
#  [('a', 'd', 'l', 'r', 't'), ['z', 'b', 'M', 'e', 'i', 'k']],
#  [('a', 'e', 'i', 'k', 'r'), ['z', 'b', 't', 'l', 'M', 'd']],
#  [('a', 'e', 'i', 'l', 'r'), ['z', 'b', 'M', 'd', 't', 'k']],
#  [('a', 'e', 'i', 'r', 't'), ['z', 'b', 'l', 'M', 'd', 'k']],
#  [('a', 'e', 'k', 'l', 'r'), ['z', 'b', 'M', 'i', 'd', 't']],
#  [('a', 'e', 'k', 'r', 't'), ['z', 'b', 'i', 'l', 'M', 'd']],
#  [('a', 'e', 'l', 'r', 't'), ['z', 'b', 'M', 'i', 'd', 'k']],
#  [('a', 'i', 'k', 'l', 'r'), ['z', 'b', 'M', 'e', 'd', 't']],
#  [('a', 'i', 'k', 'r', 't'), ['z', 'b', 'e', 'l', 'M', 'd']],
#  [('a', 'i', 'l', 'r', 't'), ['z', 'b', 'M', 'e', 'd', 'k']],
#  [('a', 'k', 'l', 'r', 't'), ['z', 'b', 'M', 'e', 'i', 'd']],
#  [('b', 'd', 'e', 'i', 'r'), ['z', 'l', 'M', 't', 'k', 'a']],
#  [('b', 'd', 'e', 'k', 'r'), ['z', 'l', 'M', 'i', 't', 'a']],
#  [('b', 'd', 'e', 'l', 'r'), ['z', 'M', 'i', 't', 'k', 'a']],
#  [('b', 'd', 'e', 'r', 't'), ['z', 'l', 'M', 'i', 'k', 'a']],
#  [('b', 'd', 'i', 'k', 'r'), ['z', 'l', 'M', 'e', 't', 'a']],
#  [('b', 'd', 'i', 'l', 'r'), ['z', 'M', 'e', 't', 'k', 'a']],
#  [('b', 'd', 'i', 'r', 't'), ['z', 'l', 'M', 'e', 'k', 'a']],
#  [('b', 'd', 'k', 'l', 'r'), ['z', 'M', 'e', 'i', 't', 'a']],
#  [('b', 'd', 'k', 'r', 't'), ['z', 'l', 'M', 'e', 'i', 'a']],
#  [('b', 'd', 'l', 'r', 't'), ['z', 'M', 'e', 'i', 'k', 'a']],
#  [('b', 'e', 'i', 'k', 'r'), ['z', 'l', 'M', 'd', 't', 'a']],
#  [('b', 'e', 'i', 'l', 'r'), ['z', 'M', 'd', 't', 'k', 'a']],
#  [('b', 'e', 'i', 'r', 't'), ['z', 'l', 'M', 'd', 'k', 'a']],
#  [('b', 'e', 'k', 'l', 'r'), ['z', 'M', 'i', 'd', 't', 'a']],
#  [('b', 'e', 'k', 'r', 't'), ['z', 'l', 'M', 'i', 'd', 'a']],
#  [('b', 'e', 'l', 'r', 't'), ['z', 'M', 'i', 'd', 'k', 'a']],
#  [('b', 'i', 'k', 'l', 'r'), ['z', 'M', 'e', 'd', 't', 'a']],
#  [('b', 'i', 'k', 'r', 't'), ['z', 'l', 'M', 'e', 'd', 'a']],
#  [('b', 'i', 'l', 'r', 't'), ['z', 'M', 'e', 'd', 'k', 'a']],
#  [('b', 'k', 'l', 'r', 't'), ['z', 'M', 'e', 'i', 'd', 'a']],
#  [('d', 'e', 'i', 'k', 'r'), ['z', 'b', 't', 'a', 'l', 'M']],
#  [('d', 'e', 'i', 'l', 'r'), ['z', 'b', 'M', 't', 'k', 'a']],
#  [('d', 'e', 'i', 'r', 't'), ['z', 'b', 'a', 'l', 'M', 'k']],
#  [('d', 'e', 'k', 'l', 'r'), ['z', 'b', 'M', 'i', 't', 'a']],
#  [('d', 'e', 'k', 'r', 't'), ['z', 'b', 'i', 'a', 'l', 'M']],
#  [('d', 'e', 'l', 'r', 't'), ['z', 'b', 'M', 'i', 'k', 'a']],
#  [('d', 'i', 'k', 'l', 'r'), ['z', 'b', 'M', 'e', 't', 'a']],
#  [('d', 'i', 'k', 'r', 't'), ['z', 'b', 'e', 'a', 'l', 'M']],
#  [('d', 'i', 'l', 'r', 't'), ['z', 'b', 'M', 'e', 'k', 'a']],
#  [('d', 'k', 'l', 'r', 't'), ['z', 'b', 'M', 'e', 'i', 'a']],
#  [('e', 'i', 'k', 'l', 'r'), ['z', 'b', 'M', 'd', 't', 'a']],
#  [('e', 'i', 'k', 'r', 't'), ['z', 'b', 'a', 'l', 'M', 'd']],
#  [('e', 'i', 'l', 'r', 't'), ['z', 'b', 'M', 'd', 'k', 'a']],
#  [('e', 'k', 'l', 'r', 't'), ['z', 'b', 'M', 'i', 'd', 'a']],
#  [('i', 'k', 'l', 'r', 't'), ['z', 'b', 'M', 'e', 'd', 'a']],
#  [('M', 'a', 'b', 'd', 'e', 'r'), ['z', 'l', 'i', 't', 'k']],
#  [('M', 'a', 'b', 'd', 'i', 'r'), ['z', 'l', 'e', 't', 'k']],
#  [('M', 'a', 'b', 'd', 'k', 'r'), ['z', 'l', 'e', 'i', 't']],
#  [('M', 'a', 'b', 'd', 'l', 'r'), ['z', 'e', 'i', 't', 'k']],
#  [('M', 'a', 'b', 'd', 'r', 't'), ['z', 'l', 'e', 'i', 'k']],
#  [('M', 'a', 'b', 'e', 'i', 'r'), ['z', 'l', 'd', 't', 'k']],
#  [('M', 'a', 'b', 'e', 'k', 'r'), ['z', 'l', 'i', 'd', 't']],
#  [('M', 'a', 'b', 'e', 'l', 'r'), ['z', 'i', 'd', 't', 'k']],
#  [('M', 'a', 'b', 'e', 'r', 't'), ['z', 'l', 'i', 'd', 'k']],
#  [('M', 'a', 'b', 'i', 'k', 'r'), ['z', 'l', 'e', 'd', 't']],
#  [('M', 'a', 'b', 'i', 'l', 'r'), ['z', 'e', 'd', 't', 'k']],
#  [('M', 'a', 'b', 'i', 'r', 't'), ['z', 'l', 'e', 'd', 'k']],
#  [('M', 'a', 'b', 'k', 'l', 'r'), ['z', 'e', 'i', 'd', 't']],
#  [('M', 'a', 'b', 'k', 'r', 't'), ['z', 'l', 'e', 'i', 'd']],
#  [('M', 'a', 'b', 'l', 'r', 't'), ['z', 'e', 'i', 'd', 'k']],
#  [('M', 'a', 'd', 'e', 'i', 'r'), ['z', 'b', 'l', 't', 'k']],
#  [('M', 'a', 'd', 'e', 'k', 'r'), ['z', 'b', 'l', 'i', 't']],
#  [('M', 'a', 'd', 'e', 'l', 'r'), ['z', 'b', 'i', 't', 'k']],
#  [('M', 'a', 'd', 'e', 'r', 't'), ['z', 'b', 'l', 'i', 'k']],
#  [('M', 'a', 'd', 'i', 'k', 'r'), ['z', 'b', 'e', 't', 'l']],
#  [('M', 'a', 'd', 'i', 'l', 'r'), ['z', 'b', 'e', 't', 'k']],
#  [('M', 'a', 'd', 'i', 'r', 't'), ['z', 'b', 'e', 'l', 'k']],
#  [('M', 'a', 'd', 'k', 'l', 'r'), ['z', 'b', 'e', 'i', 't']],
#  [('M', 'a', 'd', 'k', 'r', 't'), ['z', 'b', 'e', 'i', 'l']],
#  [('M', 'a', 'd', 'l', 'r', 't'), ['z', 'b', 'e', 'i', 'k']],
#  [('M', 'a', 'e', 'i', 'k', 'r'), ['z', 'b', 'l', 'd', 't']],
#  [('M', 'a', 'e', 'i', 'l', 'r'), ['z', 'b', 'd', 't', 'k']],
#  [('M', 'a', 'e', 'i', 'r', 't'), ['z', 'b', 'l', 'd', 'k']],
#  [('M', 'a', 'e', 'k', 'l', 'r'), ['z', 'b', 'i', 'd', 't']],
#  [('M', 'a', 'e', 'k', 'r', 't'), ['z', 'b', 'l', 'i', 'd']],
#  [('M', 'a', 'e', 'l', 'r', 't'), ['z', 'b', 'i', 'd', 'k']],
#  [('M', 'a', 'i', 'k', 'l', 'r'), ['z', 'b', 'e', 'd', 't']],
#  [('M', 'a', 'i', 'k', 'r', 't'), ['z', 'b', 'e', 'l', 'd']],
#  [('M', 'a', 'i', 'l', 'r', 't'), ['z', 'b', 'e', 'd', 'k']],
#  [('M', 'a', 'k', 'l', 'r', 't'), ['z', 'b', 'e', 'i', 'd']],
#  [('M', 'b', 'd', 'e', 'i', 'r'), ['z', 'l', 't', 'k', 'a']],
#  [('M', 'b', 'd', 'e', 'k', 'r'), ['z', 'l', 'i', 't', 'a']],
#  [('M', 'b', 'd', 'e', 'l', 'r'), ['z', 'i', 't', 'k', 'a']],
#  [('M', 'b', 'd', 'e', 'r', 't'), ['z', 'l', 'i', 'k', 'a']],
#  [('M', 'b', 'd', 'i', 'k', 'r'), ['z', 'l', 'e', 't', 'a']],
#  [('M', 'b', 'd', 'i', 'l', 'r'), ['z', 'e', 't', 'k', 'a']],
#  [('M', 'b', 'd', 'i', 'r', 't'), ['z', 'l', 'e', 'k', 'a']],
#  [('M', 'b', 'd', 'k', 'l', 'r'), ['z', 'e', 'i', 't', 'a']],
#  [('M', 'b', 'd', 'k', 'r', 't'), ['z', 'l', 'e', 'i', 'a']],
#  [('M', 'b', 'd', 'l', 'r', 't'), ['z', 'e', 'i', 'k', 'a']],
#  [('M', 'b', 'e', 'i', 'k', 'r'), ['z', 'l', 'd', 't', 'a']],
#  [('M', 'b', 'e', 'i', 'r', 't'), ['z', 'l', 'd', 'k', 'a']],
#  [('M', 'b', 'e', 'k', 'l', 'r'), ['z', 'i', 'd', 't', 'a']],
#  [('M', 'b', 'e', 'k', 'r', 't'), ['z', 'l', 'i', 'd', 'a']],
#  [('M', 'b', 'e', 'l', 'r', 't'), ['z', 'i', 'd', 'k', 'a']],
#  [('M', 'b', 'i', 'k', 'l', 'r'), ['z', 'e', 'd', 't', 'a']],
#  [('M', 'b', 'i', 'k', 'r', 't'), ['z', 'l', 'e', 'd', 'a']],
#  [('M', 'b', 'i', 'l', 'r', 't'), ['z', 'e', 'd', 'k', 'a']],
#  [('M', 'b', 'k', 'l', 'r', 't'), ['z', 'e', 'i', 'd', 'a']],
#  [('M', 'd', 'e', 'i', 'k', 'r'), ['z', 'b', 'l', 't', 'a']],
#  [('M', 'd', 'e', 'i', 'l', 'r'), ['z', 'b', 't', 'k', 'a']],
#  [('M', 'd', 'e', 'i', 'r', 't'), ['z', 'b', 'l', 'k', 'a']],
#  [('M', 'd', 'e', 'k', 'l', 'r'), ['z', 'b', 'i', 't', 'a']],
#  [('M', 'd', 'e', 'k', 'r', 't'), ['z', 'b', 'l', 'i', 'a']],
#  [('M', 'd', 'e', 'l', 'r', 't'), ['z', 'b', 'i', 'k', 'a']],
#  [('M', 'd', 'i', 'k', 'l', 'r'), ['z', 'b', 'e', 't', 'a']],
#  [('M', 'd', 'i', 'k', 'r', 't'), ['z', 'b', 'e', 'a', 'l']],
#  [('M', 'd', 'i', 'l', 'r', 't'), ['z', 'b', 'e', 'k', 'a']],
#  [('M', 'd', 'k', 'l', 'r', 't'), ['z', 'b', 'e', 'i', 'a']],
#  [('M', 'e', 'i', 'k', 'l', 'r'), ['z', 'b', 'd', 't', 'a']],
#  [('M', 'e', 'i', 'k', 'r', 't'), ['z', 'b', 'l', 'd', 'a']],
#  [('M', 'e', 'i', 'l', 'r', 't'), ['z', 'b', 'd', 'k', 'a']],
#  [('M', 'e', 'k', 'l', 'r', 't'), ['z', 'b', 'i', 'd', 'a']],
#  [('M', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'e', 'd', 'a']],
#  [('a', 'b', 'd', 'e', 'i', 'r'), ['z', 'l', 'M', 't', 'k']],
#  [('a', 'b', 'd', 'e', 'k', 'r'), ['z', 'l', 'M', 'i', 't']],
#  [('a', 'b', 'd', 'e', 'l', 'r'), ['z', 'M', 'i', 't', 'k']],
#  [('a', 'b', 'd', 'e', 'r', 't'), ['z', 'l', 'M', 'i', 'k']],
#  [('a', 'b', 'd', 'i', 'k', 'r'), ['z', 'l', 'M', 'e', 't']],
#  [('a', 'b', 'd', 'i', 'l', 'r'), ['z', 'M', 'e', 't', 'k']],
#  [('a', 'b', 'd', 'i', 'r', 't'), ['z', 'l', 'M', 'e', 'k']],
#  [('a', 'b', 'd', 'k', 'l', 'r'), ['z', 'M', 'e', 'i', 't']],
#  [('a', 'b', 'd', 'k', 'r', 't'), ['z', 'l', 'M', 'e', 'i']],
#  [('a', 'b', 'd', 'l', 'r', 't'), ['z', 'M', 'e', 'i', 'k']],
#  [('a', 'b', 'e', 'i', 'k', 'r'), ['z', 'l', 'M', 'd', 't']],
#  [('a', 'b', 'e', 'i', 'l', 'r'), ['z', 'M', 'd', 't', 'k']],
#  [('a', 'b', 'e', 'i', 'r', 't'), ['z', 'l', 'M', 'd', 'k']],
#  [('a', 'b', 'e', 'k', 'l', 'r'), ['z', 'M', 'i', 'd', 't']],
#  [('a', 'b', 'e', 'k', 'r', 't'), ['z', 'l', 'M', 'i', 'd']],
#  [('a', 'b', 'e', 'l', 'r', 't'), ['z', 'M', 'i', 'd', 'k']],
#  [('a', 'b', 'i', 'k', 'l', 'r'), ['z', 'M', 'e', 'd', 't']],
#  [('a', 'b', 'i', 'k', 'r', 't'), ['z', 'l', 'M', 'e', 'd']],
#  [('a', 'b', 'i', 'l', 'r', 't'), ['z', 'M', 'e', 'd', 'k']],
#  [('a', 'b', 'k', 'l', 'r', 't'), ['z', 'M', 'e', 'i', 'd']],
#  [('a', 'd', 'e', 'i', 'k', 'r'), ['z', 'b', 't', 'M', 'l']],
#  [('a', 'd', 'e', 'i', 'l', 'r'), ['z', 'b', 't', 'M', 'k']],
#  [('a', 'd', 'e', 'i', 'r', 't'), ['z', 'b', 'M', 'l', 'k']],
#  [('a', 'd', 'e', 'k', 'l', 'r'), ['z', 'b', 'i', 't', 'M']],
#  [('a', 'd', 'e', 'k', 'r', 't'), ['z', 'b', 'i', 'M', 'l']],
#  [('a', 'd', 'e', 'l', 'r', 't'), ['z', 'b', 'i', 'M', 'k']],
#  [('a', 'd', 'i', 'k', 'l', 'r'), ['z', 'b', 'e', 't', 'M']],
#  [('a', 'd', 'i', 'k', 'r', 't'), ['z', 'b', 'e', 'M', 'l']],
#  [('a', 'd', 'i', 'l', 'r', 't'), ['z', 'b', 'e', 'M', 'k']],
#  [('a', 'd', 'k', 'l', 'r', 't'), ['z', 'b', 'e', 'i', 'M']],
#  [('a', 'e', 'i', 'k', 'l', 'r'), ['z', 'b', 't', 'M', 'd']],
#  [('a', 'e', 'i', 'k', 'r', 't'), ['z', 'b', 'M', 'l', 'd']],
#  [('a', 'e', 'i', 'l', 'r', 't'), ['z', 'b', 'M', 'd', 'k']],
#  [('a', 'e', 'k', 'l', 'r', 't'), ['z', 'b', 'i', 'M', 'd']],
#  [('a', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'e', 'M', 'd']],
#  [('b', 'd', 'e', 'i', 'k', 'r'), ['z', 'l', 'M', 't', 'a']],
#  [('b', 'd', 'e', 'i', 'l', 'r'), ['z', 'M', 't', 'k', 'a']],
#  [('b', 'd', 'e', 'i', 'r', 't'), ['z', 'l', 'M', 'k', 'a']],
#  [('b', 'd', 'e', 'k', 'l', 'r'), ['z', 'M', 'i', 't', 'a']],
#  [('b', 'd', 'e', 'k', 'r', 't'), ['z', 'l', 'M', 'i', 'a']],
#  [('b', 'd', 'e', 'l', 'r', 't'), ['z', 'M', 'i', 'k', 'a']],
#  [('b', 'd', 'i', 'k', 'l', 'r'), ['z', 'M', 'e', 't', 'a']],
#  [('b', 'd', 'i', 'k', 'r', 't'), ['z', 'l', 'M', 'e', 'a']],
#  [('b', 'd', 'i', 'l', 'r', 't'), ['z', 'M', 'e', 'k', 'a']],
#  [('b', 'd', 'k', 'l', 'r', 't'), ['z', 'M', 'e', 'i', 'a']],
#  [('b', 'e', 'i', 'k', 'l', 'r'), ['z', 'M', 'd', 't', 'a']],
#  [('b', 'e', 'i', 'k', 'r', 't'), ['z', 'l', 'M', 'd', 'a']],
#  [('b', 'e', 'i', 'l', 'r', 't'), ['z', 'M', 'd', 'k', 'a']],
#  [('b', 'e', 'k', 'l', 'r', 't'), ['z', 'M', 'i', 'd', 'a']],
#  [('b', 'i', 'k', 'l', 'r', 't'), ['z', 'M', 'e', 'd', 'a']],
#  [('d', 'e', 'i', 'k', 'l', 'r'), ['z', 'b', 't', 'a', 'M']],
#  [('d', 'e', 'i', 'k', 'r', 't'), ['z', 'b', 'a', 'M', 'l']],
#  [('d', 'e', 'i', 'l', 'r', 't'), ['z', 'b', 'a', 'M', 'k']],
#  [('d', 'e', 'k', 'l', 'r', 't'), ['z', 'b', 'i', 'a', 'M']],
#  [('d', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'e', 'a', 'M']],
#  [('e', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'a', 'M', 'd']],
#  [('M', 'a', 'b', 'd', 'e', 'i', 'r'), ['z', 'l', 't', 'k']],
#  [('M', 'a', 'b', 'd', 'e', 'k', 'r'), ['z', 'l', 'i', 't']],
#  [('M', 'a', 'b', 'd', 'e', 'l', 'r'), ['z', 'i', 't', 'k']],
#  [('M', 'a', 'b', 'd', 'e', 'r', 't'), ['z', 'l', 'i', 'k']],
#  [('M', 'a', 'b', 'd', 'i', 'k', 'r'), ['z', 'l', 'e', 't']],
#  [('M', 'a', 'b', 'd', 'i', 'l', 'r'), ['z', 'e', 't', 'k']],
#  [('M', 'a', 'b', 'd', 'i', 'r', 't'), ['z', 'l', 'e', 'k']],
#  [('M', 'a', 'b', 'd', 'k', 'l', 'r'), ['z', 'e', 'i', 't']],
#  [('M', 'a', 'b', 'd', 'k', 'r', 't'), ['z', 'l', 'e', 'i']],
#  [('M', 'a', 'b', 'd', 'l', 'r', 't'), ['z', 'e', 'i', 'k']],
#  [('M', 'a', 'b', 'e', 'i', 'k', 'r'), ['z', 'l', 'd', 't']],
#  [('M', 'a', 'b', 'e', 'i', 'r', 't'), ['z', 'l', 'd', 'k']],
#  [('M', 'a', 'b', 'e', 'k', 'l', 'r'), ['z', 'i', 'd', 't']],
#  [('M', 'a', 'b', 'e', 'k', 'r', 't'), ['z', 'l', 'i', 'd']],
#  [('M', 'a', 'b', 'e', 'l', 'r', 't'), ['z', 'i', 'd', 'k']],
#  [('M', 'a', 'b', 'i', 'k', 'l', 'r'), ['z', 'e', 'd', 't']],
#  [('M', 'a', 'b', 'i', 'k', 'r', 't'), ['z', 'l', 'e', 'd']],
#  [('M', 'a', 'b', 'i', 'l', 'r', 't'), ['z', 'e', 'd', 'k']],
#  [('M', 'a', 'b', 'k', 'l', 'r', 't'), ['z', 'e', 'i', 'd']],
#  [('M', 'a', 'd', 'e', 'i', 'k', 'r'), ['z', 'b', 't', 'l']],
#  [('M', 'a', 'd', 'e', 'i', 'l', 'r'), ['z', 'b', 't', 'k']],
#  [('M', 'a', 'd', 'e', 'i', 'r', 't'), ['z', 'b', 'l', 'k']],
#  [('M', 'a', 'd', 'e', 'k', 'l', 'r'), ['z', 'b', 'i', 't']],
#  [('M', 'a', 'd', 'e', 'k', 'r', 't'), ['z', 'b', 'i', 'l']],
#  [('M', 'a', 'd', 'e', 'l', 'r', 't'), ['z', 'b', 'i', 'k']],
#  [('M', 'a', 'd', 'i', 'k', 'l', 'r'), ['z', 'b', 'e', 't']],
#  [('M', 'a', 'd', 'i', 'k', 'r', 't'), ['z', 'b', 'e', 'l']],
#  [('M', 'a', 'd', 'i', 'l', 'r', 't'), ['z', 'b', 'e', 'k']],
#  [('M', 'a', 'd', 'k', 'l', 'r', 't'), ['z', 'b', 'e', 'i']],
#  [('M', 'a', 'e', 'i', 'k', 'l', 'r'), ['z', 'b', 't', 'd']],
#  [('M', 'a', 'e', 'i', 'k', 'r', 't'), ['z', 'b', 'l', 'd']],
#  [('M', 'a', 'e', 'i', 'l', 'r', 't'), ['z', 'b', 'd', 'k']],
#  [('M', 'a', 'e', 'k', 'l', 'r', 't'), ['z', 'b', 'i', 'd']],
#  [('M', 'a', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'e', 'd']],
#  [('M', 'b', 'd', 'e', 'i', 'k', 'r'), ['z', 'l', 't', 'a']],
#  [('M', 'b', 'd', 'e', 'k', 'l', 'r'), ['z', 'i', 't', 'a']],
#  [('M', 'b', 'd', 'e', 'k', 'r', 't'), ['z', 'l', 'i', 'a']],
#  [('M', 'b', 'd', 'e', 'l', 'r', 't'), ['z', 'i', 'k', 'a']],
#  [('M', 'b', 'd', 'i', 'k', 'l', 'r'), ['z', 'e', 't', 'a']],
#  [('M', 'b', 'd', 'i', 'k', 'r', 't'), ['z', 'l', 'e', 'a']],
#  [('M', 'b', 'd', 'i', 'l', 'r', 't'), ['z', 'e', 'k', 'a']],
#  [('M', 'b', 'd', 'k', 'l', 'r', 't'), ['z', 'e', 'i', 'a']],
#  [('M', 'b', 'e', 'i', 'k', 'r', 't'), ['z', 'l', 'd', 'a']],
#  [('M', 'b', 'e', 'k', 'l', 'r', 't'), ['z', 'i', 'd', 'a']],
#  [('M', 'b', 'i', 'k', 'l', 'r', 't'), ['z', 'e', 'd', 'a']],
#  [('M', 'd', 'e', 'i', 'k', 'l', 'r'), ['z', 'b', 't', 'a']],
#  [('M', 'd', 'e', 'i', 'k', 'r', 't'), ['z', 'b', 'a', 'l']],
#  [('M', 'd', 'e', 'i', 'l', 'r', 't'), ['z', 'b', 'a', 'k']],
#  [('M', 'd', 'e', 'k', 'l', 'r', 't'), ['z', 'b', 'i', 'a']],
#  [('M', 'd', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'e', 'a']],
#  [('M', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'a', 'd']],
#  [('a', 'b', 'd', 'e', 'i', 'k', 'r'), ['z', 'M', 'l', 't']],
#  [('a', 'b', 'd', 'e', 'i', 'l', 'r'), ['z', 'M', 't', 'k']],
#  [('a', 'b', 'd', 'e', 'i', 'r', 't'), ['z', 'M', 'l', 'k']],
#  [('a', 'b', 'd', 'e', 'k', 'l', 'r'), ['z', 'M', 'i', 't']],
#  [('a', 'b', 'd', 'e', 'k', 'r', 't'), ['z', 'M', 'l', 'i']],
#  [('a', 'b', 'd', 'e', 'l', 'r', 't'), ['z', 'M', 'i', 'k']],
#  [('a', 'b', 'd', 'i', 'k', 'l', 'r'), ['z', 'M', 'e', 't']],
#  [('a', 'b', 'd', 'i', 'k', 'r', 't'), ['z', 'M', 'l', 'e']],
#  [('a', 'b', 'd', 'i', 'l', 'r', 't'), ['z', 'M', 'e', 'k']],
#  [('a', 'b', 'd', 'k', 'l', 'r', 't'), ['z', 'M', 'e', 'i']],
#  [('a', 'b', 'e', 'i', 'k', 'l', 'r'), ['z', 'M', 'd', 't']],
#  [('a', 'b', 'e', 'i', 'k', 'r', 't'), ['z', 'M', 'l', 'd']],
#  [('a', 'b', 'e', 'i', 'l', 'r', 't'), ['z', 'M', 'd', 'k']],
#  [('a', 'b', 'e', 'k', 'l', 'r', 't'), ['z', 'M', 'i', 'd']],
#  [('a', 'b', 'i', 'k', 'l', 'r', 't'), ['z', 'M', 'e', 'd']],
#  [('a', 'd', 'e', 'i', 'k', 'l', 'r'), ['z', 'b', 't', 'M']],
#  [('a', 'd', 'e', 'i', 'k', 'r', 't'), ['z', 'b', 'M', 'l']],
#  [('a', 'd', 'e', 'i', 'l', 'r', 't'), ['z', 'b', 'M', 'k']],
#  [('a', 'd', 'e', 'k', 'l', 'r', 't'), ['z', 'b', 'i', 'M']],
#  [('a', 'd', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'e', 'M']],
#  [('a', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'M', 'd']],
#  [('b', 'd', 'e', 'i', 'k', 'l', 'r'), ['z', 'M', 't', 'a']],
#  [('b', 'd', 'e', 'i', 'k', 'r', 't'), ['z', 'M', 'l', 'a']],
#  [('b', 'd', 'e', 'i', 'l', 'r', 't'), ['z', 'M', 'k', 'a']],
#  [('b', 'd', 'e', 'k', 'l', 'r', 't'), ['z', 'M', 'i', 'a']],
#  [('b', 'd', 'i', 'k', 'l', 'r', 't'), ['z', 'M', 'e', 'a']],
#  [('b', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'M', 'd', 'a']],
#  [('d', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'a', 'M']],
#  [('M', 'a', 'b', 'd', 'e', 'i', 'k', 'r'), ['z', 'l', 't']],
#  [('M', 'a', 'b', 'd', 'e', 'i', 'l', 'r'), ['z', 't', 'k']],
#  [('M', 'a', 'b', 'd', 'e', 'i', 'r', 't'), ['z', 'l', 'k']],
#  [('M', 'a', 'b', 'd', 'e', 'k', 'l', 'r'), ['z', 'i', 't']],
#  [('M', 'a', 'b', 'd', 'e', 'k', 'r', 't'), ['z', 'l', 'i']],
#  [('M', 'a', 'b', 'd', 'e', 'l', 'r', 't'), ['z', 'i', 'k']],
#  [('M', 'a', 'b', 'd', 'i', 'k', 'l', 'r'), ['z', 'e', 't']],
#  [('M', 'a', 'b', 'd', 'i', 'k', 'r', 't'), ['z', 'l', 'e']],
#  [('M', 'a', 'b', 'd', 'i', 'l', 'r', 't'), ['z', 'e', 'k']],
#  [('M', 'a', 'b', 'd', 'k', 'l', 'r', 't'), ['z', 'e', 'i']],
#  [('M', 'a', 'b', 'e', 'i', 'k', 'l', 'r'), ['z', 'd', 't']],
#  [('M', 'a', 'b', 'e', 'i', 'k', 'r', 't'), ['z', 'l', 'd']],
#  [('M', 'a', 'b', 'e', 'i', 'l', 'r', 't'), ['z', 'd', 'k']],
#  [('M', 'a', 'b', 'e', 'k', 'l', 'r', 't'), ['z', 'i', 'd']],
#  [('M', 'a', 'b', 'i', 'k', 'l', 'r', 't'), ['z', 'e', 'd']],
#  [('M', 'a', 'd', 'e', 'i', 'k', 'l', 'r'), ['z', 'b', 't']],
#  [('M', 'a', 'd', 'e', 'i', 'k', 'r', 't'), ['z', 'b', 'l']],
#  [('M', 'a', 'd', 'e', 'i', 'l', 'r', 't'), ['z', 'b', 'k']],
#  [('M', 'a', 'd', 'e', 'k', 'l', 'r', 't'), ['z', 'b', 'i']],
#  [('M', 'a', 'd', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'e']],
#  [('M', 'a', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'd']],
#  [('M', 'b', 'd', 'e', 'i', 'k', 'l', 'r'), ['z', 't', 'a']],
#  [('M', 'b', 'd', 'e', 'i', 'k', 'r', 't'), ['z', 'l', 'a']],
#  [('M', 'b', 'd', 'e', 'i', 'l', 'r', 't'), ['z', 'k', 'a']],
#  [('M', 'b', 'd', 'e', 'k', 'l', 'r', 't'), ['z', 'i', 'a']],
#  [('M', 'b', 'd', 'i', 'k', 'l', 'r', 't'), ['z', 'e', 'a']],
#  [('M', 'b', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'd', 'a']],
#  [('M', 'd', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'a']],
#  [('a', 'b', 'd', 'e', 'i', 'k', 'l', 'r'), ['z', 'M', 't']],
#  [('a', 'b', 'd', 'e', 'i', 'k', 'r', 't'), ['z', 'M', 'l']],
#  [('a', 'b', 'd', 'e', 'i', 'l', 'r', 't'), ['z', 'M', 'k']],
#  [('a', 'b', 'd', 'e', 'k', 'l', 'r', 't'), ['z', 'M', 'i']],
#  [('a', 'b', 'd', 'i', 'k', 'l', 'r', 't'), ['z', 'M', 'e']],
#  [('a', 'b', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'M', 'd']],
#  [('a', 'd', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'b', 'M']],
#  [('b', 'd', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'M', 'a']],
#  [('M', 'a', 'b', 'd', 'e', 'i', 'k', 'l', 'r'), ['z', 't']],
#  [('M', 'a', 'b', 'd', 'e', 'i', 'k', 'r', 't'), ['z', 'l']],
#  [('M', 'a', 'b', 'd', 'e', 'i', 'l', 'r', 't'), ['z', 'k']],
#  [('M', 'a', 'b', 'd', 'e', 'k', 'l', 'r', 't'), ['z', 'i']],
#  [('M', 'a', 'b', 'd', 'i', 'k', 'l', 'r', 't'), ['z', 'e']],
#  [('M', 'a', 'b', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'd']],
#  [('M', 'a', 'd', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'b']],
#  [('M', 'b', 'd', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'a']],
#  [('a', 'b', 'd', 'e', 'i', 'k', 'l', 'r', 't'), ['z', 'M']],
#  [('M', 'a', 'b', 'd', 'e', 'i', 'k', 'l', 'r', 't'), ['z']]]
